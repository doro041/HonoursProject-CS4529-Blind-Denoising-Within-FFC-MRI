# %%
import sys
sys.path.append('..')

from model.patch2self import patch2self

from dipy.io.image import load_nifti, save_nifti
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 sys.path.append('..')
# ----> 4 from model.patch2self import patch2self
#       6 from dipy.io.image import load_nifti, save_nifti
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'model'

# %%
import scipy.io

# Load noisy images for different SNR levels

data_groundtruth = scipy.io.load('/Users/dolorious/Downloads/simulation-1/GroundTruth.mat')
data_groundtruths = data['data']
data10 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_gaussian_SNR10.mat')
noisy_image0 = data10['data_gaussian']

data1 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_gaussian_SNR1.mat')
noisy_image1 = data1['data_gaussian']

data3 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_gaussian_SNR3.mat')
noisy_image3 = data3['data_gaussian']


data5 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_gaussian_SNR5.mat')
noisy_image5 = data5['data_gaussian']


data0 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_gaussian_SNR0.mat')
noisy_image10 = data0['data_gaussian']

rician10 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_rician_SNR10.mat')
rician_image10 = rician10['data_rician']

rician1 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_rician_SNR1.mat')
rician_image1 = rician1['data_rician']

rician3 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_rician_SNR3.mat')
rician_image3 = rician3['data_rician']

rician5 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_rician_SNR5.mat')
rician_image5 = rician5['data_rician']

rician0 = scipy.io.loadmat('/Users/dolorious/Downloads/simulation-1/GroundTruth_rician_SNR0.mat')
rician_image0 = rician0['data_rician']

# %%
import numpy as np
import scipy.io


desired_shape = (90, 90, 1, 15)

# Reshape the noisy images to the desired shape
reshaped_image0 = np.reshape(noisy_image0, desired_shape)
reshaped_image1 = np.reshape(noisy_image1, desired_shape)
reshaped_image3 = np.reshape(noisy_image3, desired_shape)
reshaped_image5 = np.reshape(noisy_image5, desired_shape)
reshaped_image10 = np.reshape(noisy_image10, desired_shape)

rician_reshaped0 = np.reshape(rician_image0,desired_shape)
rician_reshaped1 = np.reshape(rician_image1,desired_shape)
rician_reshaped3 = np.reshape(rician_image3,desired_shape)
rician_reshaped5 = np.reshape(rician_image5,desired_shape)
rician_reshaped10 = np.reshape(rician_image10,desired_shape)
# Print the shapes of the reshaped images
print("Reshaped image shape (SNR 0):", reshaped_image0.shape)
print("Reshaped image shape (SNR 1):", reshaped_image1.shape)
print("Reshaped image shape (SNR 3):", reshaped_image3.shape)
print("Reshaped image shape (SNR 5):", reshaped_image5.shape)
print("Reshaped image shape (SNR 10):", reshaped_image10.shape)


print("Reshaped image shape (SNR 0):", rician_reshaped0.shape)
print("Reshaped image shape (SNR 1):", rician_reshaped1.shape)
print("Reshaped image shape (SNR 3):", rician_reshaped3.shape)
print("Reshaped image shape (SNR 5):", rician_reshaped5.shape)
print("Reshaped image shape (SNR 10):", rician_reshaped10.shape)
# Out:
# Reshaped image shape (SNR 0): (90, 90, 1, 15)
# Reshaped image shape (SNR 1): (90, 90, 1, 15)
# Reshaped image shape (SNR 3): (90, 90, 1, 15)
# Reshaped image shape (SNR 5): (90, 90, 1, 15)
# Reshaped image shape (SNR 10): (90, 90, 1, 15)
# Reshaped image shape (SNR 0): (90, 90, 1, 15)
# Reshaped image shape (SNR 1): (90, 90, 1, 15)
# Reshaped image shape (SNR 3): (90, 90, 1, 15)
# Reshaped image shape (SNR 5): (90, 90, 1, 15)
# Reshaped image shape (SNR 10): (90, 90, 1, 15)

# %% [markdown]
# SNR 0
# Gaussian

# %%
den_p2s_0 = patch2self(reshaped_image0)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_1 = patch2self(reshaped_image1)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_3= patch2self(reshaped_image3)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_5 =  patch2self(reshaped_image5)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_10=  patch2self(reshaped_image10)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %% [markdown]
# #### Load the low level SNRs from our simulation to test how well patch2self performs

# %% [markdown]
# #### Denoise the data with Patch2Self

# %%
import matplotlib.pyplot as plt

#
sli = 0
vol = 0

# Extract noisy and denoised images for each SNR level
d10 = data10['data_gaussian'][:, :, sli, vol]
den10 = den_p2s_10[:, :, sli, vol]

d5 = data5['data_gaussian'][:, :, sli, vol]
den5 = den_p2s_5[:, :, sli, vol]

d1 = data1['data_gaussian'][:, :, sli, vol]
den1 = den_p2s_1[:, :, sli, vol]

d3 = data3['data_gaussian'][:, :, sli, vol]
den3 = den_p2s_3[:, :, sli, vol]

d0 = data0['data_gaussian'][:, :, sli, vol]
den0 = den_p2s_0[:, :, sli, vol]

fig, ax = plt.subplots(2, 5, figsize=(30, 30))
ax[0][0].imshow(d10, cmap='gray', origin='lower', interpolation='None')
ax[0][0].set_title('SNR 10')
ax[0][0].set_axis_off()
ax[1][0].imshow(den10, cmap='gray', origin='lower', interpolation='None')
ax[1][0].set_title('SNR 10: Patch2Self')
ax[1][0].set_axis_off()
ax[0][1].imshow(d5, cmap='gray', origin='lower', interpolation='None')
ax[0][1].set_title('SNR 5')
ax[0][1].set_axis_off()
ax[1][1].imshow(den5, cmap='gray', origin='lower', interpolation='None')
ax[1][1].set_title('SNR 5: Patch2Self')
ax[1][1].set_axis_off()
ax[0][2].imshow(d3, cmap='gray', origin='lower', interpolation='None')
ax[0][2].set_title('SNR 3')
ax[0][2].set_axis_off()
ax[1][2].imshow(den3, cmap='gray', origin='lower', interpolation='None')
ax[1][2].set_title('SNR 3: Patch2Self')
ax[1][2].set_axis_off()
ax[0][3].imshow(d1, cmap='gray', origin='lower', interpolation='None')
ax[0][3].set_title('SNR 1')
ax[0][3].set_axis_off()
ax[1][3].imshow(den1, cmap='gray', origin='lower', interpolation='None')
ax[1][3].set_title('SNR 1: Patch2Self')
ax[1][3].set_axis_off()
ax[0][4].imshow(d0, cmap='gray', origin='lower', interpolation='None')
ax[0][4].set_title('SNR 0')
ax[0][4].set_axis_off()
ax[1][4].imshow(den0, cmap='gray', origin='lower', interpolation='None')
ax[1][4].set_title('SNR 0: Patch2Self')
ax[1][4].set_axis_off()
plt.tight_layout()
plt.subplots_adjust(hspace=0, top=0.45)
plt.show()

# %%
den_p2s_0_rici = patch2self(rician_reshaped0)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_1_rici = patch2self(rician_reshaped1)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_3_rici = patch2self(rician_reshaped3)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_5_rici = patch2self(rician_reshaped5)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
den_p2s_10_rici = patch2self(rician_reshaped10)
# Out:
# (15, 1, 8100)
# Patch Extraction Done...
# Training with patch-radius:  [0 0 0]
#  -> Trained to Denoise Volume:  0
# Denoising Volume  0  Complete...
#  -> Trained to Denoise Volume:  1
# Denoising Volume  1  Complete...
#  -> Trained to Denoise Volume:  2
# Denoising Volume  2  Complete...
#  -> Trained to Denoise Volume:  3
# Denoising Volume  3  Complete...
#  -> Trained to Denoise Volume:  4
# Denoising Volume  4  Complete...
#  -> Trained to Denoise Volume:  5
# Denoising Volume  5  Complete...
#  -> Trained to Denoise Volume:  6
# Denoising Volume  6  Complete...
#  -> Trained to Denoise Volume:  7
# Denoising Volume  7  Complete...
#  -> Trained to Denoise Volume:  8
# Denoising Volume  8  Complete...
#  -> Trained to Denoise Volume:  9
# Denoising Volume  9  Complete...
#  -> Trained to Denoise Volume:  10
# Denoising Volume  10  Complete...
#  -> Trained to Denoise Volume:  11
# Denoising Volume  11  Complete...
#  -> Trained to Denoise Volume:  12
# ...

# %%
import matplotlib.pyplot as plt


sli = 0
vol = 0

# Extract noisy and denoised images for each SNR level
dr10 = rician10['data_rician'][:, :, sli, vol]
denr10 = den_p2s_10_rici[:, :, sli, vol]

dr5 = rician5['data_rician'][:, :, sli, vol]
denr5 = den_p2s_5_rici[:, :, sli, vol]

dr1 = rician1['data_rician'][:, :, sli, vol]
denr1 = den_p2s_1_rici[:, :, sli, vol]

dr3 = rician3['data_rician'][:, :, sli, vol]
denr3 = den_p2s_3_rici[:, :, sli, vol]

dr0 = rician0['data_rician'][:, :, sli, vol]
denr0 = den_p2s_0_rici[:, :, sli, vol]

fig, ax = plt.subplots(2, 5, figsize=(30, 30))
ax[0][0].imshow(dr10, cmap='gray', origin='lower', interpolation='None')
ax[0][0].set_title('SNR 10')
ax[0][0].set_axis_off()
ax[1][0].imshow(denr10, cmap='gray', origin='lower', interpolation='None')
ax[1][0].set_title('SNR 10: Patch2Self')
ax[1][0].set_axis_off()
ax[0][1].imshow(dr5, cmap='gray', origin='lower', interpolation='None')
ax[0][1].set_title('SNR 5')
ax[0][1].set_axis_off()
ax[1][1].imshow(denr5, cmap='gray', origin='lower', interpolation='None')
ax[1][1].set_title('SNR 5: Patch2Self')
ax[1][1].set_axis_off()
ax[0][2].imshow(dr3, cmap='gray', origin='lower', interpolation='None')
ax[0][2].set_title('SNR 3')
ax[0][2].set_axis_off()
ax[1][2].imshow(denr3, cmap='gray', origin='lower', interpolation='None')
ax[1][2].set_title('SNR 3: Patch2Self')
ax[1][2].set_axis_off()
ax[0][3].imshow(dr1, cmap='gray', origin='lower', interpolation='None')
ax[0][3].set_title('SNR 1')
ax[0][3].set_axis_off()
ax[1][3].imshow(denr1, cmap='gray', origin='lower', interpolation='None')
ax[1][3].set_title('SNR 1: Patch2Self')
ax[1][3].set_axis_off()
ax[0][4].imshow(dr0, cmap='gray', origin='lower', interpolation='None')
ax[0][4].set_title('SNR 0')
ax[0][4].set_axis_off()
ax[1][4].imshow(denr0, cmap='gray', origin='lower', interpolation='None')
ax[1][4].set_title('SNR 0: Patch2Self')
ax[1][4].set_axis_off()
plt.tight_layout()
plt.subplots_adjust(hspace=0, top=0.45)
plt.show()
